# %% [markdown]
# ## Initial Code

# %%
# Importing necessary libraries for data analysis and manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# For handling warnings
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df_aapl = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/stocks/AAPL.csv')

# %%
import numpy as np
from scipy.stats import boxcox

df_aapl['Close_log'] = np.log(df_aapl['Close'] + 1)
df_aapl['Close_sqrt'] = np.sqrt(df_aapl['Close'])
df_aapl['Close_boxcox'], _ = boxcox(df_aapl['Close'] + 1)

# %% [markdown]
# This code calculates the skewness of the 'Close' column in the `df_aapl` DataFrame before and after applying various transformations:
#
# 1. **Original Skewness**: Calculates the skewness of the original 'Close' data.
# 2. **Log Transformation Skewness**: Calculates the skewness of the 'Close_log' column after applying the log transformation.
# 3. **Square Root Transformation Skewness**: Calculates the skewness of the 'Close_sqrt' column after applying the square root transformation.
# 4. **Box-Cox Transformation Skewness**: Calculates the skewness of the 'Close_boxcox' column after applying the Box-Cox transformation.
#
# The printed results help assess how each transformation affects the distribution's symmetry and the success of skewness correction.

# %%
skew_original = df_aapl['Close'].skew()
skew_log = df_aapl['Close_log'].skew()
skew_sqrt = df_aapl['Close_sqrt'].skew()
skew_boxcox = pd.Series(df_aapl['Close_boxcox']).skew()

print(f"Original Skewness: {skew_original}")
print(f"Log Transformation Skewness: {skew_log}")
print(f"Square Root Transformation Skewness: {skew_sqrt}")
print(f"Box-Cox Transformation Skewness: {skew_boxcox}")
# Out:
# Original Skewness: 2.5045276102319933
# Log Transformation Skewness: 0.8535555176510303
# Square Root Transformation Skewness: 1.6211545809555206
# Box-Cox Transformation Skewness: 0.43527466713563334

# %%
df_aapl['Open_log'] = np.log(df_aapl['Open'])
df_aapl['High_log'] = np.log(df_aapl['High'])
df_aapl['Low_log'] = np.log(df_aapl['Low'])
df_aapl['Adj Close_log'] = np.log(df_aapl['Adj Close'])
df_aapl['Volume_log'] = np.log(df_aapl['Volume'])


df_aapl['Open_sqrt'] = np.sqrt(df_aapl['Open'])
df_aapl['High_sqrt'] = np.sqrt(df_aapl['High'])
df_aapl['Low_sqrt'] = np.sqrt(df_aapl['Low'])
df_aapl['Adj Close_sqrt'] = np.sqrt(df_aapl['Adj Close'])
df_aapl['Volume_sqrt'] = np.sqrt(df_aapl['Volume'])

from scipy.stats import boxcox
df_aapl['Open_boxcox'], _ = boxcox(df_aapl['Open'])
df_aapl['High_boxcox'], _ = boxcox(df_aapl['High'])
df_aapl['Low_boxcox'], _ = boxcox(df_aapl['Low'])
df_aapl['Adj Close_boxcox'], _ = boxcox(df_aapl['Adj Close'])

# %% [markdown]
# This helps compare how the transformations reduce skewness in the data, aiming for a more normal distribution.

# %%
skewness_before = df_aapl[['Open', 'High', 'Low', 'Adj Close', 'Volume']].skew()
skewness_after = df_aapl[['Open_log', 'High_log', 'Low_log', 'Adj Close_log',
                          'Open_sqrt', 'High_sqrt', 'Low_sqrt', 'Adj Close_sqrt', 'Volume_sqrt',
                          'Open_boxcox', 'High_boxcox', 'Low_boxcox', 'Adj Close_boxcox']].skew()

print("Skewness Before Transformation:\n", skewness_before)
print("\nSkewness After Transformation:\n", skewness_after)
# Out:
# Skewness Before Transformation:
#  Open         2.504632
# High         2.502208
# Low          2.506714
# Adj Close    2.550677
# Volume       3.565699
# dtype: float64
#
# Skewness After Transformation:
#  Open_log            0.482872
# High_log            0.481997
# Low_log             0.484246
# Adj Close_log       0.494009
# Open_sqrt           1.620771
# High_sqrt           1.621456
# Low_sqrt            1.620661
# Adj Close_sqrt      1.679402
# Volume_sqrt         1.299776
# Open_boxcox         0.181226
# High_boxcox         0.179749
# Low_boxcox          0.182882
# Adj Close_boxcox    0.180085
# dtype: float64

# %% [markdown]
# - Applied Box-Cox transformation to the 'Open', 'High', 'Low', 'Adj Close', and 'Close' columns.
# - Recalculated skewness after the transformation to reduce skew and normalize the data for modeling.

# %%
from scipy import stats

df_aapl['Open_boxcox'], _ = stats.boxcox(df_aapl['Open'] + 1)
df_aapl['High_boxcox'], _ = stats.boxcox(df_aapl['High'] + 1)
df_aapl['Low_boxcox'], _ = stats.boxcox(df_aapl['Low'] + 1)
df_aapl['Adj Close_boxcox'], _ = stats.boxcox(df_aapl['Adj Close'] + 1)
df_aapl['Close_boxcox'], _ = stats.boxcox(df_aapl['Close'] + 1)

skewness_after_boxcox = df_aapl[['Open_boxcox', 'High_boxcox', 'Low_boxcox', 'Adj Close_boxcox', 'Close_boxcox']].skew()

print("Skewness After Box-Cox Transformation:")
print(skewness_after_boxcox)
# Out:
# Skewness After Box-Cox Transformation:
# Open_boxcox         0.435237
# High_boxcox         0.433381
# Low_boxcox          0.437331
# Adj Close_boxcox    0.458762
# Close_boxcox        0.435275
# dtype: float64

# %% [markdown]
# Feature Selection

# %%
df_aapl_cleaned = df_aapl[['Date', 'Open', 'High', 'Low', 'Adj Close', 'Close', 'Volume',
                           'Open_boxcox', 'High_boxcox', 'Low_boxcox', 'Adj Close_boxcox',
                           'Close_boxcox']]

print(df_aapl_cleaned.head())
# Out:
#          Date      Open      High       Low  Adj Close     Close     Volume  \
# 0  1980-12-12  0.128348  0.128906  0.128348   0.098943  0.128348  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652   0.093781  0.121652  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723   0.086898  0.112723  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513   0.089049  0.115513   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862   0.091630  0.118862   73449600
#
#    Open_boxcox  High_boxcox  Low_boxcox  Adj Close_boxcox  Close_boxcox
# 0     0.117689     0.118173    0.117674          0.092374      0.117689
# 1     0.112503     0.112516    0.112016          0.087857      0.112030
# 2     0.104886     0.104897    0.104395          0.081785      0.104407
# 3     0.106798     0.107287    0.106786          0.083688      0.106798
# 4     0.109657     0.110145    0.109644          0.085966      0.109657

# %% [markdown]
# ### Train Validation Test Split
#
# The code splits the data into training, validation, and test sets. The features `X` and target `Y` are split as follows:
#
# - 70% for training (`X_train`, `Y_train`)
# - 15% for validation (`X_val`, `Y_val`)
# - 15% for testing (`X_test`, `Y_test`)
#
# The split is done using a 30% test size, followed by splitting the remaining 70% into validation and test sets without shuffling (time series data).

# %%
from sklearn.model_selection import train_test_split

X = df_aapl_cleaned[['Open_boxcox', 'High_boxcox', 'Low_boxcox']]
Y = df_aapl_cleaned['Close_boxcox']

X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, shuffle=False)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, shuffle=False)

print(f"Training set: {X_train.shape}, Validation set: {X_val.shape}, Test set: {X_test.shape}")
# Out:
# Training set: (7736, 3), Validation set: (1658, 3), Test set: (1658, 3)

# %% [markdown]
# ## Decision Tree Regressor

# %% [markdown]
# ###**Initial Basic DTR**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def compute_metrics(actual, predicted, label):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    accuracy = 1 - (mape / 100)

    print(f"{label} MAE: {mae}")
    print(f"{label} MSE: {mse}")
    print(f"{label} RMSE: {rmse}")
    print(f"{label} R²: {r2}")
    print(f"{label} MAPE: {mape}%")
    print(f"{label} Accuracy: {accuracy * 100}%\n")

dt_regressor = DecisionTreeRegressor(random_state=42)

dt_regressor.fit(X_train, Y_train)

Y_train_pred = dt_regressor.predict(X_train)
Y_val_pred = dt_regressor.predict(X_val)
Y_test_pred = dt_regressor.predict(X_test)

compute_metrics(Y_train, Y_train_pred, "Training")
compute_metrics(Y_val, Y_val_pred, "Validation")
compute_metrics(Y_test, Y_test_pred, "Test")
# Out:
# Training MAE: 6.294350837355037e-05
# Training MSE: 1.0289611088082219e-07
# Training RMSE: 0.0003207742366226162
# Training R²: 0.9999994120927935
# Training MAPE: 0.025296519708453247%
# Training Accuracy: 99.97470348029155%
#
# Validation MAE: 0.13517441496303997
# Validation MSE: 0.02390980530996259
# Validation RMSE: 0.15462795772421814
# Validation R²: -3.065226342696154
# Validation MAPE: 7.563909101395194%
# Validation Accuracy: 92.4360908986048%
#
# Test MAE: 0.4033505341723914
# Test MSE: 0.16872672380815157
# Test RMSE: 0.4107635862733594
# Test R²: -26.95770602109714
# Test MAPE: 19.889610417803492%
# Test Accuracy: 80.1103895821965%

# %% [markdown]
#  **Conclusion:**
# - The model performs **exceptionally well on the training data** (with near-perfect R² and minimal error metrics), but **fails to generalize well to validation and test datasets**, as reflected by high error metrics and low R² values on both.
# - The **overfitting issue** is evident, where the model fits the training data very well but struggles to generalize to unseen data.

# %% [markdown]
# ###**Pruning**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Define the metrics function
def compute_metrics(actual, predicted, label):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    accuracy = 1 - (mape / 100)

    print(f"{label} MAE: {mae}")
    print(f"{label} MSE: {mse}")
    print(f"{label} RMSE: {rmse}")
    print(f"{label} R²: {r2}")
    print(f"{label} MAPE: {mape}%")
    print(f"{label} Accuracy: {accuracy * 100}%\n")


dt_regressor_pruned = DecisionTreeRegressor(
    random_state=42,
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt'
)

dt_regressor_pruned.fit(X_train, Y_train)

Y_train_pred = dt_regressor_pruned.predict(X_train)
Y_val_pred = dt_regressor_pruned.predict(X_val)
Y_test_pred = dt_regressor_pruned.predict(X_test)

compute_metrics(Y_train, Y_train_pred, "Training")
compute_metrics(Y_val, Y_val_pred, "Validation")
compute_metrics(Y_test, Y_test_pred, "Test")
# Out:
# Training MAE: 0.010289240712896866
# Training MSE: 0.00016927183542729895
# Training RMSE: 0.013010451007835929
# Training R²: 0.9990328484619886
# Training MAPE: 3.661852663100275%
# Training Accuracy: 96.33814733689972%
#
# Validation MAE: 0.17345221636020575
# Validation MSE: 0.03596721479583069
# Validation RMSE: 0.18965024333185204
# Validation R²: -5.115268073742864
# Validation MAPE: 9.755296125375532%
# Validation Accuracy: 90.24470387462446%
#
# Test MAE: 0.4424893023879134
# Test MSE: 0.20183185311874033
# Test RMSE: 0.4492570011905661
# Test R²: -32.443164709361746
# Test MAPE: 21.834432754083227%
# Test Accuracy: 78.16556724591676%

# %% [markdown]
# **Conclusion:**
# - The model performs well on the **training data** (with a high R² and low error metrics), but struggles to generalize on both **validation** and **test data**.
# - Despite using **pruning**, the model suffers from **overfitting**. It fits the training data extremely well, but its performance drops significantly on unseen data.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def compute_metrics(actual, predicted, label):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    accuracy = 1 - (mape / 100)

    print(f"{label} MAE: {mae}")
    print(f"{label} MSE: {mse}")
    print(f"{label} RMSE: {rmse}")
    print(f"{label} R²: {r2}")
    print(f"{label} MAPE: {mape}%")
    print(f"{label} Accuracy: {accuracy * 100}%\n")

dt_regressor_pruned = DecisionTreeRegressor(
    random_state=42,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=1,
)

dt_regressor_pruned.fit(X_train, Y_train)

Y_train_pred = dt_regressor_pruned.predict(X_train)
Y_val_pred = dt_regressor_pruned.predict(X_val)
Y_test_pred = dt_regressor_pruned.predict(X_test)

compute_metrics(Y_train, Y_train_pred, "Training")
compute_metrics(Y_val, Y_val_pred, "Validation")
compute_metrics(Y_test, Y_test_pred, "Test")
# Out:
# Training MAE: 0.0016280691676729513
# Training MSE: 5.646074075619677e-06
# Training RMSE: 0.0023761468968941453
# Training R²: 0.9999677405918582
# Training MAPE: 0.5614076380114963%
# Training Accuracy: 99.43859236198851%
#
# Validation MAE: 0.1351520248106317
# Validation MSE: 0.023909535081898445
# Validation RMSE: 0.15462708392095625
# Validation R²: -3.0651803976024716
# Validation MAPE: 7.562522311292043%
# Validation Accuracy: 92.43747768870796%
#
# Test MAE: 0.4033505341723914
# Test MSE: 0.16872672380815157
# Test RMSE: 0.4107635862733594
# Test R²: -26.95770602109714
# Test MAPE: 19.889610417803492%
# Test Accuracy: 80.1103895821965%

# %% [markdown]
# **Conclusion:**
# - **Training performance** is outstanding, with very low error metrics and almost perfect R², but the model struggles significantly with **validation** and **test data**.
# - Loosening the pruning parameters has allowed the model to fit the **training data** even more accurately but at the cost of generalizing well to unseen data, as indicated by the large discrepancy in validation and test metrics.

# %% [markdown]
# ###**Cross Validation**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def compute_metrics(actual, predicted, label):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    accuracy = 1 - (mape / 100)

    print(f"{label} MAE: {mae}")
    print(f"{label} MSE: {mse}")
    print(f"{label} RMSE: {rmse}")
    print(f"{label} R²: {r2}")
    print(f"{label} MAPE: {mape}%")
    print(f"{label} Accuracy: {accuracy * 100}%\n")

dt_regressor = DecisionTreeRegressor(
    random_state=42,
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=3,
    max_features='sqrt'
)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

train_mae_list, train_mse_list, train_rmse_list, train_r2_list, train_mape_list, train_accuracy_list = [], [], [], [], [], []
val_mae_list, val_mse_list, val_rmse_list, val_r2_list, val_mape_list, val_accuracy_list = [], [], [], [], [], []

for train_index, val_index in kf.split(X):
    X_train_cv, X_val_cv = X.iloc[train_index], X.iloc[val_index]
    Y_train_cv, Y_val_cv = Y.iloc[train_index], Y.iloc[val_index]

    dt_regressor.fit(X_train_cv, Y_train_cv)

    Y_train_pred_cv = dt_regressor.predict(X_train_cv)
    Y_val_pred_cv = dt_regressor.predict(X_val_cv)

    compute_metrics(Y_train_cv, Y_train_pred_cv, "Train (CV)")

    compute_metrics(Y_val_cv, Y_val_pred_cv, "Validation (CV)")

    train_mae_list.append(mean_absolute_error(Y_train_cv, Y_train_pred_cv))
    train_mse_list.append(mean_squared_error(Y_train_cv, Y_train_pred_cv))
    train_rmse_list.append(np.sqrt(mean_squared_error(Y_train_cv, Y_train_pred_cv)))
    train_r2_list.append(r2_score(Y_train_cv, Y_train_pred_cv))
    train_mape_list.append(np.mean(np.abs((Y_train_cv - Y_train_pred_cv) / Y_train_cv)) * 100)
    train_accuracy_list.append(1 - (np.mean(np.abs((Y_train_cv - Y_train_pred_cv) / Y_train_cv)) * 100) / 100)

    val_mae_list.append(mean_absolute_error(Y_val_cv, Y_val_pred_cv))
    val_mse_list.append(mean_squared_error(Y_val_cv, Y_val_pred_cv))
    val_rmse_list.append(np.sqrt(mean_squared_error(Y_val_cv, Y_val_pred_cv)))
    val_r2_list.append(r2_score(Y_val_cv, Y_val_pred_cv))
    val_mape_list.append(np.mean(np.abs((Y_val_cv - Y_val_pred_cv) / Y_val_cv)) * 100)
    val_accuracy_list.append(1 - (np.mean(np.abs((Y_val_cv - Y_val_pred_cv) / Y_val_cv)) * 100) / 100)

print("\nAverage Cross-Validation Metrics:")

# Train metrics
print("\nTraining Metrics:")
print(f"Average MAE (Train): {np.mean(train_mae_list)}")
print(f"Average MSE (Train): {np.mean(train_mse_list)}")
print(f"Average RMSE (Train): {np.mean(train_rmse_list)}")
print(f"Average R² (Train): {np.mean(train_r2_list)}")
print(f"Average MAPE (Train): {np.mean(train_mape_list)}%")
print(f"Average Accuracy (Train): {np.mean(train_accuracy_list) * 100}%")

# Validation metrics
print("\nValidation Metrics:")
print(f"Average MAE (Validation): {np.mean(val_mae_list)}")
print(f"Average MSE (Validation): {np.mean(val_mse_list)}")
print(f"Average RMSE (Validation): {np.mean(val_rmse_list)}")
print(f"Average R² (Validation): {np.mean(val_r2_list)}")
print(f"Average MAPE (Validation): {np.mean(val_mape_list)}%")
print(f"Average Accuracy (Validation): {np.mean(val_accuracy_list) * 100}%")

# Test metrics (use your actual test set here)
print("\nTest Metrics:")
compute_metrics(Y_test, dt_regressor.predict(X_test), "Test")
# Out:
# Train (CV) MAE: 0.002139978806416879
# Train (CV) MSE: 1.0324806171414852e-05
# Train (CV) RMSE: 0.003213223641674331
# Train (CV) R²: 0.9999813982055806
# Train (CV) MAPE: 0.6222887665286777%
# Train (CV) Accuracy: 99.37771123347132%
#
# Validation (CV) MAE: 0.0029264363730980734
# Validation (CV) MSE: 2.205618993019325e-05
# Validation (CV) RMSE: 0.004696401806723234
# Validation (CV) R²: 0.9999610789933855
# Validation (CV) MAPE: 0.7917693243148141%
# Validation (CV) Accuracy: 99.20823067568519%
#
# Train (CV) MAE: 0.0021166976118361432
# Train (CV) MSE: 1.0419272443285559e-05
# Train (CV) RMSE: 0.003227889781774706
# Train (CV) R²: 0.9999813723243124
# Train (CV) MAPE: 0.6019936836674006%
# Train (CV) Accuracy: 99.3980063163326%
#
# Validation (CV) MAE: 0.002811897664986526
# Validation (CV) MSE: 1.961151698506994e-05
# Validation (CV) RMSE: 0.004428489244095546
# Validation (CV) R²: 0.9999642647902678
# Validation (CV) MAPE: 0.7642266338052603%
# Validation (CV) Accuracy: 99.23577336619473%
#
# Train (CV) MAE: 0.0021121307347430223
# Train (CV) MSE: 9.826030194570049e-06
# Train (CV) RMSE: 0.0031346499317419876
# Train (CV) R²: 0.9999823876302305
# Train (CV) MAPE: 0.6185247405356318%
# Train (CV) Accuracy: 99.38147525946437%
#
# Validation (CV) MAE: 0.0029087588539874055
# Validation (CV) MSE: 2.0358925960871147e-05
# Validation (CV) RMSE: 0.004512086652633252
# Validation (CV) R²: 0.9999633335653041
# Validation (CV) MAPE: 0.7846763967412116%
# Validation (CV) Accuracy: 99.21532360325878%
#
# Train (CV) MAE: 0.0021165596868443284
# Train (CV) MSE: 9.989420462669509e-06
# Train (CV) RMSE: 0.00316060444577766
# Train (CV) R²: 0.9999820455876128
# Train (CV) MAPE: 0.618529036501689%
# Train (CV) Accuracy: 99.3814709634983%
#
# Validation (CV) MAE: 0.002951044774815073
# Validation (CV) MSE: 2.1422100575074174e-05
# Validation (CV) RMSE: 0.00462840151402989
# Validation (CV) R²: 0.9999618243956004
# Validation (CV) MAPE: 0.7944698511034808%
# Validation (CV) Accuracy: 99.20553014889651%
#
# Train (CV) MAE: 0.0020912047454649607
# Train (CV) MSE: 9.877813984382205e-06
# Train (CV) RMSE: 0.003142898977756397
# Train (CV) R²: 0.9999823025128728
# Train (CV) MAPE: 0.6051553482118283%
# Train (CV) Accuracy: 99.39484465178818%
#
# Validation (CV) MAE: 0.0029118067940831316
# Validation (CV) MSE: 2.0675333754831173e-05
# Validation (CV) RMSE: 0.00454701371834649
# Validation (CV) R²: 0.999962690607797
# Validation (CV) MAPE: 0.7432864846432672%
# Validation (CV) Accuracy: 99.25671351535674%
#
#
# Average Cross-Validation Metrics:
#
# Training Metrics:
# Average MAE (Train): 0.0021153143170610663
# Average MSE (Train): 1.0087468651264435e-05
# Average RMSE (Train): 0.003175853355745017
# Average R² (Train): 0.9999819012521218
# Average MAPE (Train): 0.6132983150890454%
# Average Accuracy (Train): 99.38670168491095%
#
# Validation Metrics:
# Average MAE (Validation): 0.002901988892194042
# Average MSE (Validation): 2.0824813441207936e-05
# Average RMSE (Validation): 0.0045624785871656815
# Average R² (Validation): 0.999962638470471
# Average MAPE (Validation): 0.7756857381216068%
# Average Accuracy (Validation): 99.22431426187839%
#
# Test Metrics:
# Test MAE: 0.001036593479045731
# Test MSE: 2.139734937428624e-06
# Test RMSE: 0.0014627832845054746
# Test R²: 0.9996454498789906
# Test MAPE: 0.05198349169569901%
# Test Accuracy: 99.9480165083043%

# %% [markdown]
# **Conclusion:**
# - The model demonstrates **exceptional performance** across **training**, **validation**, and **test data**.
# - K-fold cross-validation provides consistent and reliable metrics, showing the model's **ability to generalize well** to new data.
# - **Test performance** is particularly strong, with near-perfect accuracy and very low error across all metrics.

# %% [markdown]
# ###**Hyperparameter tuning using GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

dt_regressor = DecisionTreeRegressor(random_state=42)

param_grid = {
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2', None]
}

grid_search = GridSearchCV(estimator=dt_regressor, param_grid=param_grid,
                           cv=5, scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)
grid_search.fit(X_train, Y_train)

print("Best parameters found: ", grid_search.best_params_)

best_dt_regressor = grid_search.best_estimator_

Y_train_pred = best_dt_regressor.predict(X_train)
Y_val_pred = best_dt_regressor.predict(X_val)
Y_test_pred = best_dt_regressor.predict(X_test)

def compute_metrics(actual, predicted, label):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    accuracy = 1 - (mape / 100)

    print(f"{label} MAE: {mae}")
    print(f"{label} MSE: {mse}")
    print(f"{label} RMSE: {rmse}")
    print(f"{label} R²: {r2}")
    print(f"{label} MAPE: {mape}%")
    print(f"{label} Accuracy: {accuracy * 100}%\n")

print("Training Metrics:")
compute_metrics(Y_train, Y_train_pred, "Training")

print("Validation Metrics:")
compute_metrics(Y_val, Y_val_pred, "Validation")

print("Test Metrics:")
compute_metrics(Y_test, Y_test_pred, "Test")
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# Best parameters found:  {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# Training Metrics:
# Training MAE: 0.001112201980807158
# Training MSE: 3.423285795228113e-06
# Training RMSE: 0.0018502123648998006
# Training R²: 0.9999804407147028
# Training MAPE: 0.34379328677675175%
# Training Accuracy: 99.65620671322326%
#
# Validation Metrics:
# Validation MAE: 0.13920448379915923
# Validation MSE: 0.02507657173150102
# Validation RMSE: 0.15835583895613392
# Validation R²: -3.263603934279261
# Validation MAPE: 7.793954154789697%
# Validation Accuracy: 92.2060458452103%
#
# Test Metrics:
# Test MAE: 0.40760882633414786
# Test MSE: 0.1721800256964996
# Test RMSE: 0.41494581055422114
# Test R²: -27.529911756012677
# Test MAPE: 20.10120679878782%
# Test Accuracy: 79.89879320121219%

# %% [markdown]
# **Conclusion:**
# - The model shows **excellent performance on training data** but suffers from **overfitting** as indicated by the substantial drop in performance on validation and test data.
# - **Validation and test metrics** reveal that the model struggles with generalization, as evidenced by the negative R² and high error rates.
# - While GridSearchCV helped in optimizing hyperparameters, the model may need further adjustments, such as **regularization or pruning**, to improve generalization and avoid overfitting.

# %% [markdown]
# ###**Hyperband optimization using optuna**

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 7.2 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 15.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
import optuna
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Define the objective function
def objective(trial):
    max_depth = trial.suggest_int('max_depth', 3, 20)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    model = DecisionTreeRegressor(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )

    model.fit(X_train, Y_train)

    Y_val_pred = model.predict(X_val)
    mae_val = mean_absolute_error(Y_val, Y_val_pred)
    mse_val = mean_squared_error(Y_val, Y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(Y_val, Y_val_pred)

    # Calculate MAPE for validation
    mape_val = np.mean(np.abs((Y_val - Y_val_pred) / Y_val)) * 100

    # Return the validation MAPE for optimization
    return mape_val

study = optuna.create_study(direction='minimize')

study.optimize(objective, n_trials=50)

print(f"Best trial: {study.best_trial.params}")

best_params = study.best_trial.params
final_model = DecisionTreeRegressor(**best_params, random_state=42)
final_model.fit(X_train, Y_train)

# Evaluate on Train, Validation, and Test sets
# Train metrics
Y_train_pred = final_model.predict(X_train)
mae_train = mean_absolute_error(Y_train, Y_train_pred)
mse_train = mean_squared_error(Y_train, Y_train_pred)
rmse_train = np.sqrt(mse_train)
r2_train = r2_score(Y_train, Y_train_pred)

# Calculate MAPE for training
mape_train = np.mean(np.abs((Y_train - Y_train_pred) / Y_train)) * 100

# Validation metrics
Y_val_pred = final_model.predict(X_val)
mae_val = mean_absolute_error(Y_val, Y_val_pred)
mse_val = mean_squared_error(Y_val, Y_val_pred)
rmse_val = np.sqrt(mse_val)
r2_val = r2_score(Y_val, Y_val_pred)

# Calculate MAPE for validation
mape_val = np.mean(np.abs((Y_val - Y_val_pred) / Y_val)) * 100

# Test metrics
Y_test_pred = final_model.predict(X_test)
mae_test = mean_absolute_error(Y_test, Y_test_pred)
mse_test = mean_squared_error(Y_test, Y_test_pred)
rmse_test = np.sqrt(mse_test)
r2_test = r2_score(Y_test, Y_test_pred)

# Calculate MAPE for test
mape_test = np.mean(np.abs((Y_test - Y_test_pred) / Y_test)) * 100

# Print final model performance on all sets
print("Final Model Performance:")
print(f"Train MAE: {mae_train}")
print(f"Train MSE: {mse_train}")
print(f"Train RMSE: {rmse_train}")
print(f"Train R²: {r2_train}")
print(f"Train MAPE: {mape_train}")

print(f"\nValidation MAE: {mae_val}")
print(f"Validation MSE: {mse_val}")
print(f"Validation RMSE: {rmse_val}")
print(f"Validation R²: {r2_val}")
print(f"Validation MAPE: {mape_val}")

print(f"\nTest MAE: {mae_test}")
print(f"Test MSE: {mse_test}")
print(f"Test RMSE: {rmse_test}")
print(f"Test R²: {r2_test}")
print(f"Test MAPE: {mape_test}")
# Out:
# [I 2024-12-12 18:32:14,665] A new study created in memory with name: no-name-4712776e-14da-410c-861d-993eb326e7a3
# [I 2024-12-12 18:32:14,760] Trial 0 finished with value: 7.795513012695916 and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 0 with value: 7.795513012695916.
# [I 2024-12-12 18:32:14,852] Trial 1 finished with value: 7.983207464989938 and parameters: {'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 7.795513012695916.
# [I 2024-12-12 18:32:15,040] Trial 2 finished with value: 8.280201801222344 and parameters: {'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 0 with value: 7.795513012695916.
# [I 2024-12-12 18:32:15,148] Trial 3 finished with value: 7.956342146497021 and parameters: {'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: 7.795513012695916.
# [I 2024-12-12 18:32:15,191] Trial 4 finished with value: 10.609296210773152 and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: 7.795513012695916.
# [I 2024-12-12 18:32:15,257] Trial 5 finished with value: 8.280225303932118 and parameters: {'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 0 with value: 7.795513012695916.
# [I 2024-12-12 18:32:15,347] Trial 6 finished with value: 7.7863609513012895 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 6 with value: 7.7863609513012895.
# [I 2024-12-12 18:32:15,419] Trial 7 finished with value: 7.786663735409594 and parameters: {'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 6 with value: 7.7863609513012895.
# [I 2024-12-12 18:32:15,484] Trial 8 finished with value: 7.943241884430659 and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 6 with value: 7.7863609513012895.
# [I 2024-12-12 18:32:15,578] Trial 9 finished with value: 8.184000391308803 and parameters: {'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 6 with value: 7.7863609513012895.
# [I 2024-12-12 18:32:15,769] Trial 10 finished with value: 7.85626875270224 and parameters: {'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 6 with value: 7.7863609513012895.
# [I 2024-12-12 18:32:15,874] Trial 11 finished with value: 7.7844756533645825 and parameters: {'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:15,959] Trial 12 finished with value: 7.858933860421883 and parameters: {'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,030] Trial 13 finished with value: 7.7844756533645825 and parameters: {'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,115] Trial 14 finished with value: 7.785447777070946 and parameters: {'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,211] Trial 15 finished with value: 7.943241748433476 and parameters: {'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,324] Trial 16 finished with value: 7.78456002873625 and parameters: {'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,449] Trial 17 finished with value: 7.7847778178394345 and parameters: {'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,779] Trial 18 finished with value: 7.959222423397285 and parameters: {'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 11 with value: 7.7844756533645825.
# [I 2024-12-12 18:32:16,956] Trial 19 finished with value: 7.7843386511520425 and parameters: {'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 19 with value: 7.7843386511520425.
# [I 2024-12-12 18:32:17,068] Trial 20 finished with value: 7.784305841264824 and parameters: {'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:17,286] Trial 21 finished with value: 7.784305841264824 and parameters: {'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:17,406] Trial 22 finished with value: 7.784305841264824 and parameters: {'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:17,535] Trial 23 finished with value: 7.784337975377807 and parameters: {'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:17,658] Trial 24 finished with value: 7.784305841264824 and parameters: {'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:17,856] Trial 25 finished with value: 7.784305841264824 and parameters: {'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:18,005] Trial 26 finished with value: 7.784337975377807 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:18,081] Trial 27 finished with value: 10.609296210773113 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 20 with value: 7.784305841264824.
# [I 2024-12-12 18:32:18,219] Trial 28 finished with value: 7.782801332167959 and parameters: {'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 28 with value: 7.782801332167959.
# [I 2024-12-12 18:32:18,334] Trial 29 finished with value: 7.981914017677831 and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 28 with value: 7.782801332167959.
# [I 2024-12-12 18:32:18,390] Trial 30 finished with value: 7.692914425055189 and parameters: {'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,452] Trial 31 finished with value: 7.693016740333418 and parameters: {'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,508] Trial 32 finished with value: 7.692914425055189 and parameters: {'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,563] Trial 33 finished with value: 7.782801332167959 and parameters: {'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,618] Trial 34 finished with value: 7.782801332167959 and parameters: {'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,662] Trial 35 finished with value: 7.6954463669564435 and parameters: {'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,705] Trial 36 finished with value: 7.6954014170205 and parameters: {'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,748] Trial 37 finished with value: 7.793093306172924 and parameters: {'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,801] Trial 38 finished with value: 7.793093306172924 and parameters: {'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,855] Trial 39 finished with value: 7.795678894779535 and parameters: {'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,896] Trial 40 finished with value: 7.785875956365643 and parameters: {'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,943] Trial 41 finished with value: 7.6954463669564435 and parameters: {'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:18,994] Trial 42 finished with value: 7.6954014170205 and parameters: {'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,059] Trial 43 finished with value: 7.6954014170205 and parameters: {'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,125] Trial 44 finished with value: 7.952915613129048 and parameters: {'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,191] Trial 45 finished with value: 7.785972273666282 and parameters: {'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,254] Trial 46 finished with value: 7.959207086372841 and parameters: {'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,334] Trial 47 finished with value: 7.795095002961966 and parameters: {'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,419] Trial 48 finished with value: 7.7843386511520425 and parameters: {'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# [I 2024-12-12 18:32:19,486] Trial 49 finished with value: 12.769876222259164 and parameters: {'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 30 with value: 7.692914425055189.
# Best trial: {'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None}
# Final Model Performance:
# Train MAE: 0.0009209888620397383
# Train MSE: 2.1357325026510428e-06
# Train RMSE: 0.0014614145553712822
# Train R²: 0.9999877972790364
# Train MAPE: 0.2869052286459768
#
# Validation MAE: 0.13743725151870892
# Validation MSE: 0.024569257347623746
# Validation RMSE: 0.15674583677923873
# Validation R²: -3.177348618912589
# Validation MAPE: 7.692914425055189
#
# Test MAE: 0.4057736346996098
# Test MSE: 0.17068731300833043
# Test RMSE: 0.41314321125770714
# Test R²: -27.282572024831467
# Test MAPE: 20.010015331990765

# %% [markdown]
# **Conclusion:**
# - While the model performs **exceptionally well on training data**, it shows significant **generalization issues** on both validation and test sets.
# - The **Optuna hyperparameter optimization** has helped to improve training metrics, but it may still overfit on the training set, leading to **poor performance on unseen data**.
# - **Further tuning or regularization techniques** could improve generalization and mitigate overfitting.

# %% [markdown]
# ## Bagging Regressor

# %% [markdown]
# ###**Basic Model**

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
import numpy as np

bagging_model = BaggingRegressor(n_estimators=100, random_state=42)

bagging_model.fit(X_train, Y_train)

Y_train_pred = bagging_model.predict(X_train)
Y_val_pred = bagging_model.predict(X_val)
Y_test_pred = bagging_model.predict(X_test)

def evaluate_model(Y_true, Y_pred):
    mae = mean_absolute_error(Y_true, Y_pred)
    mse = mean_squared_error(Y_true, Y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(Y_true, Y_pred)
    mape = mean_absolute_percentage_error(Y_true, Y_pred)

    return mae, mse, rmse, r2, mape

# Evaluate the model on all datasets
train_metrics = evaluate_model(Y_train, Y_train_pred)
val_metrics = evaluate_model(Y_val, Y_val_pred)
test_metrics = evaluate_model(Y_test, Y_test_pred)

# Display the results
print(f"Training set metrics: MAE={train_metrics[0]}, MSE={train_metrics[1]}, RMSE={train_metrics[2]}, R²={train_metrics[3]}, MAPE={train_metrics[4]}")
print(f"Validation set metrics: MAE={val_metrics[0]}, MSE={val_metrics[1]}, RMSE={val_metrics[2]}, R²={val_metrics[3]}, MAPE={val_metrics[4]}")
print(f"Test set metrics: MAE={test_metrics[0]}, MSE={test_metrics[1]}, RMSE={test_metrics[2]}, R²={test_metrics[3]}, MAPE={test_metrics[4]}")
# Out:
# Training set metrics: MAE=0.0008732125022284934, MSE=1.8691580116169827e-06, RMSE=0.0013671715370124492, R²=0.9999893203790154, MAPE=0.0025500260474208424
# Validation set metrics: MAE=0.13800668869839053, MSE=0.02474056021408138, RMSE=0.1572913227552028, R²=-3.2064741143432345, MAPE=0.07725309735866118
# Test set metrics: MAE=0.4063966726089382, MSE=0.17119332589861455, RMSE=0.4137551521112632, R²=-27.366417424719245, MAPE=0.20040974355426008

# %% [markdown]
# Overfitting: The model performs exceptionally well on the training set but poorly on the validation and test sets, indicated by the drastically worse R² and higher error metrics (MAE, MSE, etc.) on those datasets.

# %% [markdown]
# ###**Regularization**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor

# Define a regularized DecisionTreeRegressor as the base estimator
tree_regressor = DecisionTreeRegressor(max_depth=5, random_state=42)

# Initialize the Bagging Regressor with the regularized base estimator
bagging_model_reg = BaggingRegressor(n_estimators=100,
                                    max_samples=0.8, max_features=0.8, random_state=42)

# Train the model on the training data
bagging_model_reg.fit(X_train, Y_train)

# Predictions on the training, validation, and test sets
Y_train_pred_reg = bagging_model_reg.predict(X_train)
Y_val_pred_reg = bagging_model_reg.predict(X_val)
Y_test_pred_reg = bagging_model_reg.predict(X_test)

# Evaluate the model on all datasets
train_metrics_reg = evaluate_model(Y_train, Y_train_pred_reg)
val_metrics_reg = evaluate_model(Y_val, Y_val_pred_reg)
test_metrics_reg = evaluate_model(Y_test, Y_test_pred_reg)

# Display the results
print(f"Training set metrics (regularized): MAE={train_metrics_reg[0]}, MSE={train_metrics_reg[1]}, RMSE={train_metrics_reg[2]}, R²={train_metrics_reg[3]}, MAPE={train_metrics_reg[4]}")
print(f"Validation set metrics (regularized): MAE={val_metrics_reg[0]}, MSE={val_metrics_reg[1]}, RMSE={val_metrics_reg[2]}, R²={val_metrics_reg[3]}, MAPE={val_metrics_reg[4]}")
print(f"Test set metrics (regularized): MAE={test_metrics_reg[0]}, MSE={test_metrics_reg[1]}, RMSE={test_metrics_reg[2]}, R²={test_metrics_reg[3]}, MAPE={test_metrics_reg[4]}")
# Out:
# Training set metrics (regularized): MAE=0.0013058228798433875, MSE=3.641757363067161e-06, RMSE=0.0019083389015233014, R²=0.9999791924555798, MAPE=0.004120529645240297
# Validation set metrics (regularized): MAE=0.13815464235852487, MSE=0.02478106837704831, RMSE=0.15742003804169374, R²=-3.213361449854861, MAPE=0.07733803189986108
# Test set metrics (regularized): MAE=0.4065432743934606, MSE=0.17131250434555467, RMSE=0.4138991475535492, R²=-27.386165072918654, MAPE=0.20048259061564627

# %% [markdown]
# Despite adding regularization, the model still appears to be overfitting. This suggests the following possibilities:
#
# Base Estimator Complexity: The base DecisionTreeRegressor might still be too complex for the problem. You could try further reducing the tree's depth or introducing other constraints like min_samples_split or min_samples_leaf.
# Model Choice: Bagging with decision trees may not be the best approach for this problem. You could experiment with other ensemble methods like Random Forest or Gradient Boosting, which have built-in regularization.

# %% [markdown]
# ###**Cross-Validation**

# %%
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
import numpy as np

# Train the model on the training set
bagging_model_reg.fit(X_train, Y_train)

# Make predictions on the training, validation, and test sets
Y_train_pred = bagging_model_reg.predict(X_train)
Y_val_pred = bagging_model_reg.predict(X_val)
Y_test_pred = bagging_model_reg.predict(X_test)

# Calculate metrics for training set
train_mae = mean_absolute_error(Y_train, Y_train_pred)
train_mse = mean_squared_error(Y_train, Y_train_pred)
train_rmse = np.sqrt(train_mse)
train_r2 = r2_score(Y_train, Y_train_pred)
train_mape = mean_absolute_percentage_error(Y_train, Y_train_pred)

# Calculate metrics for validation set
val_mae = mean_absolute_error(Y_val, Y_val_pred)
val_mse = mean_squared_error(Y_val, Y_val_pred)
val_rmse = np.sqrt(val_mse)
val_r2 = r2_score(Y_val, Y_val_pred)
val_mape = mean_absolute_percentage_error(Y_val, Y_val_pred)

# Calculate metrics for test set
test_mae = mean_absolute_error(Y_test, Y_test_pred)
test_mse = mean_squared_error(Y_test, Y_test_pred)
test_rmse = np.sqrt(test_mse)
test_r2 = r2_score(Y_test, Y_test_pred)
test_mape = mean_absolute_percentage_error(Y_test, Y_test_pred)

# Print all metrics for train, validation, and test sets
print(f"Training set metrics:")
print(f"MAE: {train_mae}, MSE: {train_mse}, RMSE: {train_rmse}, R²: {train_r2}, MAPE: {train_mape}")
print(f"\nValidation set metrics:")
print(f"MAE: {val_mae}, MSE: {val_mse}, RMSE: {val_rmse}, R²: {val_r2}, MAPE: {val_mape}")
print(f"\nTest set metrics:")
print(f"MAE: {test_mae}, MSE: {test_mse}, RMSE: {test_rmse}, R²: {test_r2}, MAPE: {test_mape}")
# Out:
# Training set metrics:
# MAE: 0.0013058228798433875, MSE: 3.641757363067161e-06, RMSE: 0.0019083389015233014, R²: 0.9999791924555798, MAPE: 0.004120529645240297
#
# Validation set metrics:
# MAE: 0.13815464235852487, MSE: 0.02478106837704831, RMSE: 0.15742003804169374, R²: -3.213361449854861, MAPE: 0.07733803189986108
#
# Test set metrics:
# MAE: 0.4065432743934606, MSE: 0.17131250434555467, RMSE: 0.4138991475535492, R²: -27.386165072918654, MAPE: 0.20048259061564627

# %% [markdown]
# The model is overfitting the training data, as seen from the excellent training performance but poor validation and test results.
# Regularization or model complexity reduction could help improve generalization.
# You could try alternative models or further tweak hyperparameters (like reducing tree depth or changing the base estimator).

# %% [markdown]
# ###**Hyperparameter tuning using GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
import numpy as np

# Define the parameter grid for tuning
param_grid = {
    'n_estimators': [50, 100, 200],  # Number of trees
    'max_samples': [0.5, 0.7, 1.0],  # Fraction of samples to train each base estimator
    'max_features': [0.5, 0.7, 1.0],  # Fraction of features to train each base estimator
}

# Create the Bagging Regressor without specifying the base_estimator explicitly
bagging_model = BaggingRegressor(random_state=42)

# Perform grid search with 5-fold cross-validation
grid_search = GridSearchCV(bagging_model, param_grid, cv=5, n_jobs=-1, scoring='neg_mean_absolute_error')

# Fit grid search to the training data
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Get the best model
best_bagging_model = grid_search.best_estimator_

# Now manually set the base_estimator to DecisionTreeRegressor in the best model
best_bagging_model.base_estimator = DecisionTreeRegressor(random_state=42)

# Evaluate the best model on the training, validation, and test sets
Y_train_pred = best_bagging_model.predict(X_train)
Y_val_pred = best_bagging_model.predict(X_val)
Y_test_pred = best_bagging_model.predict(X_test)

# Calculate metrics for training set
train_mae = mean_absolute_error(Y_train, Y_train_pred)
train_mse = mean_squared_error(Y_train, Y_train_pred)
train_rmse = np.sqrt(train_mse)
train_r2 = r2_score(Y_train, Y_train_pred)
train_mape = mean_absolute_percentage_error(Y_train, Y_train_pred)

# Calculate metrics for validation set
val_mae = mean_absolute_error(Y_val, Y_val_pred)
val_mse = mean_squared_error(Y_val, Y_val_pred)
val_rmse = np.sqrt(val_mse)
val_r2 = r2_score(Y_val, Y_val_pred)
val_mape = mean_absolute_percentage_error(Y_val, Y_val_pred)

# Calculate metrics for test set
test_mae = mean_absolute_error(Y_test, Y_test_pred)
test_mse = mean_squared_error(Y_test, Y_test_pred)
test_rmse = np.sqrt(test_mse)
test_r2 = r2_score(Y_test, Y_test_pred)
test_mape = mean_absolute_percentage_error(Y_test, Y_test_pred)

# Print all metrics for train, validation, and test sets
print(f"Training set metrics after hyperparameter tuning:")
print(f"MAE: {train_mae}, MSE: {train_mse}, RMSE: {train_rmse}, R²: {train_r2}, MAPE: {train_mape}")
print(f"\nValidation set metrics after hyperparameter tuning:")
print(f"MAE: {val_mae}, MSE: {val_mse}, RMSE: {val_rmse}, R²: {val_r2}, MAPE: {val_mape}")
print(f"\nTest set metrics after hyperparameter tuning:")
print(f"MAE: {test_mae}, MSE: {test_mse}, RMSE: {test_rmse}, R²: {test_r2}, MAPE: {test_mape}")
# Out:
# Best Hyperparameters: {'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# Training set metrics after hyperparameter tuning:
# MAE: 0.0013970896700768508, MSE: 4.6881845516611124e-06, RMSE: 0.002165221594124055, R²: 0.9999732135893241, MAPE: 0.004070045623765808
#
# Validation set metrics after hyperparameter tuning:
# MAE: 0.13939557603727515, MSE: 0.02514355082063873, RMSE: 0.1585671807803832, R²: -3.274991946604856, MAPE: 0.07804651993494914
#
# Test set metrics after hyperparameter tuning:
# MAE: 0.407850385786475, MSE: 0.17237700757717447, RMSE: 0.4151831012663864, R²: -27.562551289259666, MAPE: 0.20113209992547984

# %% [markdown]
# Training Set: The performance on the training set is excellent (R² close to 1, low MAE, MSE, RMSE), which indicates that the model fits the training data well.
# Validation and Test Sets: The performance drops significantly (negative R² values, higher MAE, MSE, RMSE, and MAPE). This suggests that the model might be overfitting the training data and not generalizing well to unseen data.

# %% [markdown]
# ###**Using Optuna**

# %%
# Objective function for optimization
def objective(trial):
    # Hyperparameters to tune
    n_estimators = trial.suggest_int('n_estimators', 50, 200)  # Number of trees
    max_samples = trial.suggest_float('max_samples', 0.5, 1.0)  # Fraction of samples to train each base estimator
    max_features = trial.suggest_float('max_features', 0.5, 1.0)  # Fraction of features to train each base estimator

    # Create the Bagging Regressor (no need for base_estimator argument)
    model = BaggingRegressor(
        n_estimators=n_estimators,
        max_samples=max_samples,
        max_features=max_features,
        random_state=42
    )

    # Fit the model on the training set
    model.fit(X_train, Y_train)

    # Predict on the validation set
    Y_val_pred = model.predict(X_val)

    # Calculate validation metrics
    val_mae = mean_absolute_error(Y_val, Y_val_pred)
    val_mse = mean_squared_error(Y_val, Y_val_pred)
    val_rmse = np.sqrt(val_mse)
    val_r2 = r2_score(Y_val, Y_val_pred)
    val_mape = mean_absolute_percentage_error(Y_val, Y_val_pred)

    # Return the validation MAE as the objective to minimize
    return val_mae

# %%
import optuna
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
import numpy as np

# Create an Optuna study with Hyperband optimization (tune using early stopping)
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)  # Number of trials to perform

# Get the best hyperparameters from the study
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# [I 2024-12-12 19:08:19,333] A new study created in memory with name: no-name-fdf41bef-9fe1-4e24-b260-8ab98e3fb4da
# [I 2024-12-12 19:08:23,342] Trial 0 finished with value: 0.1385641018776892 and parameters: {'n_estimators': 183, 'max_samples': 0.9182502379182215, 'max_features': 0.5015017775497446}. Best is trial 0 with value: 0.1385641018776892.
# [I 2024-12-12 19:08:24,893] Trial 1 finished with value: 0.13942924081615862 and parameters: {'n_estimators': 197, 'max_samples': 0.5983117502567056, 'max_features': 0.5786802046063424}. Best is trial 0 with value: 0.1385641018776892.
# [I 2024-12-12 19:08:25,982] Trial 2 finished with value: 0.13786317967480427 and parameters: {'n_estimators': 69, 'max_samples': 0.7531418605554339, 'max_features': 0.8611914561102552}. Best is trial 2 with value: 0.13786317967480427.
# [I 2024-12-12 19:08:28,296] Trial 3 finished with value: 0.1388361457400624 and parameters: {'n_estimators': 175, 'max_samples': 0.5846582846208493, 'max_features': 0.9697597989463977}. Best is trial 2 with value: 0.13786317967480427.
# [I 2024-12-12 19:08:31,055] Trial 4 finished with value: 0.1377285956378758 and parameters: {'n_estimators': 150, 'max_samples': 0.9360642138803875, 'max_features': 0.9109111207016867}. Best is trial 4 with value: 0.1377285956378758.
# [I 2024-12-12 19:08:33,707] Trial 5 finished with value: 0.13939337145258854 and parameters: {'n_estimators': 200, 'max_samples': 0.5802166195445368, 'max_features': 0.6030658273976766}. Best is trial 4 with value: 0.1377285956378758.
# [I 2024-12-12 19:08:36,300] Trial 6 finished with value: 0.13811404292247037 and parameters: {'n_estimators': 100, 'max_samples': 0.8051642275786101, 'max_features': 0.9314661293772457}. Best is trial 4 with value: 0.1377285956378758.
# [I 2024-12-12 19:08:38,389] Trial 7 finished with value: 0.13806987839949186 and parameters: {'n_estimators': 123, 'max_samples': 0.8940288162614564, 'max_features': 0.7501320539073106}. Best is trial 4 with value: 0.1377285956378758.
# [I 2024-12-12 19:08:39,023] Trial 8 finished with value: 0.13894748297131748 and parameters: {'n_estimators': 75, 'max_samples': 0.6627648868456776, 'max_features': 0.626301944236949}. Best is trial 4 with value: 0.1377285956378758.
# [I 2024-12-12 19:08:41,918] Trial 9 finished with value: 0.13824198279194055 and parameters: {'n_estimators': 194, 'max_samples': 0.715017597329715, 'max_features': 0.9950820574356226}. Best is trial 4 with value: 0.1377285956378758.
# [I 2024-12-12 19:08:44,756] Trial 10 finished with value: 0.1376683158955043 and parameters: {'n_estimators': 157, 'max_samples': 0.9915815614801617, 'max_features': 0.8139429780286978}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:08:48,096] Trial 11 finished with value: 0.13772035660674475 and parameters: {'n_estimators': 153, 'max_samples': 0.9774930955023449, 'max_features': 0.8244889488058862}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:08:51,835] Trial 12 finished with value: 0.13772670702887402 and parameters: {'n_estimators': 150, 'max_samples': 0.9980381814086697, 'max_features': 0.7964130048302374}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:08:54,412] Trial 13 finished with value: 0.1378161000330485 and parameters: {'n_estimators': 144, 'max_samples': 0.9967230842898731, 'max_features': 0.8286050153091858}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:08:56,447] Trial 14 finished with value: 0.13817046377956427 and parameters: {'n_estimators': 123, 'max_samples': 0.8380976247707073, 'max_features': 0.7027178879012447}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:08:59,068] Trial 15 finished with value: 0.13789048193867587 and parameters: {'n_estimators': 160, 'max_samples': 0.8580859005442354, 'max_features': 0.7202000386755416}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:09:00,853] Trial 16 finished with value: 0.1377094111191677 and parameters: {'n_estimators': 101, 'max_samples': 0.9462465769161512, 'max_features': 0.8688520606455559}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:09:03,087] Trial 17 finished with value: 0.13817973089030386 and parameters: {'n_estimators': 102, 'max_samples': 0.7811355964471173, 'max_features': 0.8791775971999012}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:09:04,121] Trial 18 finished with value: 0.1389485442176436 and parameters: {'n_estimators': 54, 'max_samples': 0.5186084212930837, 'max_features': 0.7741768655370398}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:09:06,621] Trial 19 finished with value: 0.13773192664119857 and parameters: {'n_estimators': 106, 'max_samples': 0.8745915332300122, 'max_features': 0.6852814295456087}. Best is trial 10 with value: 0.1376683158955043.
# [I 2024-12-12 19:09:08,192] Trial 20 finished with value: 0.13751632163742533 and parameters: {'n_estimators': 90, 'max_samples': 0.9386091108985148, 'max_features': 0.9352422618947205}. Best is trial 20 with value: 0.13751632163742533.
# [I 2024-12-12 19:09:09,778] Trial 21 finished with value: 0.13750811773089575 and parameters: {'n_estimators': 91, 'max_samples': 0.9470508997861544, 'max_features': 0.922776875298201}. Best is trial 21 with value: 0.13750811773089575.
# [I 2024-12-12 19:09:11,208] Trial 22 finished with value: 0.13761675146551866 and parameters: {'n_estimators': 83, 'max_samples': 0.9425326171582243, 'max_features': 0.9380898872534144}. Best is trial 21 with value: 0.13750811773089575.
# [I 2024-12-12 19:09:12,640] Trial 23 finished with value: 0.13756256549720214 and parameters: {'n_estimators': 83, 'max_samples': 0.9160144869767466, 'max_features': 0.9460513699303881}. Best is trial 21 with value: 0.13750811773089575.
# [I 2024-12-12 19:09:14,036] Trial 24 finished with value: 0.13768039582909117 and parameters: {'n_estimators': 87, 'max_samples': 0.8401645145239931, 'max_features': 0.9969021820947134}. Best is trial 21 with value: 0.13750811773089575.
# [I 2024-12-12 19:09:14,897] Trial 25 finished with value: 0.13728151211698758 and parameters: {'n_estimators': 51, 'max_samples': 0.900497737648986, 'max_features': 0.8993407953669181}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:15,761] Trial 26 finished with value: 0.13730610616059477 and parameters: {'n_estimators': 51, 'max_samples': 0.8924646974830936, 'max_features': 0.8921516652382329}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:16,801] Trial 27 finished with value: 0.13765048274017308 and parameters: {'n_estimators': 52, 'max_samples': 0.8112971316066917, 'max_features': 0.8973094902416597}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:18,439] Trial 28 finished with value: 0.13741780423342662 and parameters: {'n_estimators': 64, 'max_samples': 0.8888241605057351, 'max_features': 0.850135573227849}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:20,073] Trial 29 finished with value: 0.13735489259191486 and parameters: {'n_estimators': 63, 'max_samples': 0.9039587679147509, 'max_features': 0.8523980783055425}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:21,469] Trial 30 finished with value: 0.13802179592814165 and parameters: {'n_estimators': 62, 'max_samples': 0.742724513417625, 'max_features': 0.7900023645583799}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:23,105] Trial 31 finished with value: 0.13743744951354045 and parameters: {'n_estimators': 64, 'max_samples': 0.9040481279228871, 'max_features': 0.8555874222383039}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:23,984] Trial 32 finished with value: 0.13831003178795653 and parameters: {'n_estimators': 57, 'max_samples': 0.8790739347789779, 'max_features': 0.5022998752222042}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:25,731] Trial 33 finished with value: 0.13752086861777466 and parameters: {'n_estimators': 70, 'max_samples': 0.8443384868015924, 'max_features': 0.8544606583364808}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:26,800] Trial 34 finished with value: 0.13734869441821337 and parameters: {'n_estimators': 50, 'max_samples': 0.9034697469884398, 'max_features': 0.8826986123548427}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:27,656] Trial 35 finished with value: 0.1376790432482922 and parameters: {'n_estimators': 51, 'max_samples': 0.8064744239265956, 'max_features': 0.8964673438595407}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:28,969] Trial 36 finished with value: 0.13774780028323694 and parameters: {'n_estimators': 74, 'max_samples': 0.9674316266817049, 'max_features': 0.8955230656836153}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:29,721] Trial 37 finished with value: 0.13802979245988145 and parameters: {'n_estimators': 50, 'max_samples': 0.6828596577469208, 'max_features': 0.9660824513313225}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:30,781] Trial 38 finished with value: 0.13759990747416145 and parameters: {'n_estimators': 61, 'max_samples': 0.9158358827734384, 'max_features': 0.9698410941167338}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:32,368] Trial 39 finished with value: 0.13767836614679285 and parameters: {'n_estimators': 76, 'max_samples': 0.774685095245056, 'max_features': 0.7466184308300725}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:35,165] Trial 40 finished with value: 0.13791160509934314 and parameters: {'n_estimators': 112, 'max_samples': 0.8641383665441214, 'max_features': 0.8381826782044826}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:36,698] Trial 41 finished with value: 0.13738662780356725 and parameters: {'n_estimators': 66, 'max_samples': 0.8921524537091866, 'max_features': 0.8806198848817611}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:37,909] Trial 42 finished with value: 0.13736193112804349 and parameters: {'n_estimators': 69, 'max_samples': 0.906540311011283, 'max_features': 0.8795668088217087}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:38,938] Trial 43 finished with value: 0.1376806357732203 and parameters: {'n_estimators': 59, 'max_samples': 0.9201003123811257, 'max_features': 0.9096812069706135}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:40,235] Trial 44 finished with value: 0.1377701338433493 and parameters: {'n_estimators': 73, 'max_samples': 0.9658888996254087, 'max_features': 0.9611616698273051}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:41,521] Trial 45 finished with value: 0.13761799909598402 and parameters: {'n_estimators': 79, 'max_samples': 0.8325317569342873, 'max_features': 0.8117471599522501}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:42,515] Trial 46 finished with value: 0.13779531600851092 and parameters: {'n_estimators': 57, 'max_samples': 0.924414794919082, 'max_features': 0.8819969672661225}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:44,726] Trial 47 finished with value: 0.13829620573474075 and parameters: {'n_estimators': 136, 'max_samples': 0.8567877086118275, 'max_features': 0.904818217442795}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:45,837] Trial 48 finished with value: 0.13749195637703882 and parameters: {'n_estimators': 68, 'max_samples': 0.8220391083681655, 'max_features': 0.7771844654718796}. Best is trial 25 with value: 0.13728151211698758.
# [I 2024-12-12 19:09:50,118] Trial 49 finished with value: 0.13766857124898865 and parameters: {'n_estimators': 177, 'max_samples': 0.9024939579562721, 'max_features': 0.8363124296244333}. Best is trial 25 with value: 0.13728151211698758.
# Best Hyperparameters: {'n_estimators': 51, 'max_samples': 0.900497737648986, 'max_features': 0.8993407953669181}

# %%
# Retrieve the best hyperparameters
best_n_estimators = best_params['n_estimators']
best_max_samples = best_params['max_samples']
best_max_features = best_params['max_features']

# Create the final Bagging Regressor model with the best hyperparameters
final_model = BaggingRegressor(
    n_estimators=best_n_estimators,
    max_samples=best_max_samples,
    max_features=best_max_features,
    random_state=42
)

# Train the model on the full training set
final_model.fit(X_train, Y_train)

# Predict on the training, validation, and test sets
Y_train_pred = final_model.predict(X_train)
Y_val_pred = final_model.predict(X_val)
Y_test_pred = final_model.predict(X_test)

# Calculate performance metrics for training, validation, and test sets
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    return mae, mse, rmse, r2, mape

# Calculate metrics for each set
train_metrics = calculate_metrics(Y_train, Y_train_pred)
val_metrics = calculate_metrics(Y_val, Y_val_pred)
test_metrics = calculate_metrics(Y_test, Y_test_pred)

# Print the results
print("Training set metrics:")
print(f"MAE: {train_metrics[0]}, MSE: {train_metrics[1]}, RMSE: {train_metrics[2]}, R²: {train_metrics[3]}, MAPE: {train_metrics[4]}")

print("Validation set metrics:")
print(f"MAE: {val_metrics[0]}, MSE: {val_metrics[1]}, RMSE: {val_metrics[2]}, R²: {val_metrics[3]}, MAPE: {val_metrics[4]}")

print("Test set metrics:")
print(f"MAE: {test_metrics[0]}, MSE: {test_metrics[1]}, RMSE: {test_metrics[2]}, R²: {test_metrics[3]}, MAPE: {test_metrics[4]}")
# Out:
# Training set metrics:
# MAE: 0.0012352644087070266, MSE: 3.2713379031666993e-06, RMSE: 0.001808684025242303, R²: 0.9999813088841601, MAPE: 0.0039212548406858585
# Validation set metrics:
# MAE: 0.13728151211698758, MSE: 0.024528190494293826, RMSE: 0.1566147837667116, R²: -3.1703662929670546, MAPE: 0.07683947720067068
# Test set metrics:
# MAE: 0.40562442649669206, MSE: 0.1705662457617684, RMSE: 0.41299666555768755, R²: -27.262511406028636, MAPE: 0.2000260111179373

# %% [markdown]
# model's performance on the training set is excellent, with an R² close to 1. However, the performance on the validation and test sets shows a significant drop, especially with negative R² values and high MAE, MSE, RMSE, and MAPE values. This suggests that the model may be overfitting to the training data.
